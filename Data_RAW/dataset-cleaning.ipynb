# %%
import pandas as pd 

import numpy as np

# %%
pd.set_option('display.max_rows', None)

# %%
#read agricultural.xslx data in dataframe

df = pd.read_excel('/Users/rajatsharma/IBM-CarbonSense-powered-by-Watsonx/Data_processed/industry/agriculture.xlsx')

# %%
#list al;l columns in the dataframe
columns = df.columns.tolist()

# %%
columns
# Out:
# ['.',
#  'industry',
#  '..1',
#  '..2',
#  'unit',
#  'process',
#  'total',
#  'eco-costs of',
#  'eco-costs of.1',
#  'eco-costs of.2',
#  'eco-costs of.3',
#  'unnamed: 11',
#  'unnamed: 12',
#  'unnamed: 13',
#  'unnamed: 14',
#  'human',
#  'human tox',
#  'ecotoxicity',
#  'metals',
#  'plastic',
#  'fossil tra',
#  'biodiversity',
#  'unnamed: 22',
#  'unnamed: 23',
#  'carbon',
#  'ced',
#  'non-renewable',
#  'non-renewable.1',
#  'non-renewable.2',
#  'renewable',
#  'renewable.1',
#  'renewable.2',
#  'recipe2016',
#  'recipe',
#  'recipe.1',
#  'recipe.2',
#  'recipe.3',
#  'recipe.4',
#  'recipe.5',
#  'global warming,',
#  'global warming, .1',
#  'global warming, .2',
#  'stratospheric',
#  'ionizing',
#  'ozone formation,',
#  'fine particulate',
#  'ozone formation, .1',
#  'terrestrial',
#  'freshwater',
#  'marine',
#  'terrestrial.1',
#  'freshwater.1',
#  'marine.1',
#  'human .1',
#  'human .2',
#  'land use',
#  'mineral resource',
#  'fossil resource',
#  'water consumption,',
#  'water consumption,.1',
#  'water consumption, .1',
#  'ef 3.1',
#  'acidification',
#  'climate change',
#  'ecotoxicity.1',
#  'particulate',
#  'eutrophication,',
#  'eutrophication, .1',
#  'eutrophication,.1',
#  'human toxicity,',
#  'human toxicity, non-cancer',
#  'ionising radiation',
#  'land use.1',
#  'ozone depletion',
#  'photochemical ozone formation',
#  'resource use,',
#  'resource use,.1',
#  'water use',
#  'traci',
#  'traci.1',
#  'traci.2',
#  'traci.3',
#  'traci.4',
#  'traci.5',
#  'traci.6',
#  'traci.7',
#  'traci.8',
#  'traci.9',
#  'carbon.1',
#  'pollutants',
#  'water',
#  'biodiversity.1',
#  'resources',
#  'classyfire',
#  'chemicals,plastics, and wood',
#  'note:',
#  'unnamed: 107',
#  'unnamed: 110',
#  'unnamed: 118',
#  'source_file',
#  'region']

# %%
# remove all columns except carbon and resource use
columns_to_keep = ['.', 'industry', '..2', 'process', 'carbon', 'region']
columns_to_remove = [col for col in columns if col not in columns_to_keep]

# %%
columns_to_remove
# Out:
# ['..1',
#  'unit',
#  'total',
#  'eco-costs of',
#  'eco-costs of.1',
#  'eco-costs of.2',
#  'eco-costs of.3',
#  'unnamed: 11',
#  'unnamed: 12',
#  'unnamed: 13',
#  'unnamed: 14',
#  'human',
#  'human tox',
#  'ecotoxicity',
#  'metals',
#  'plastic',
#  'fossil tra',
#  'biodiversity',
#  'unnamed: 22',
#  'unnamed: 23',
#  'ced',
#  'non-renewable',
#  'non-renewable.1',
#  'non-renewable.2',
#  'renewable',
#  'renewable.1',
#  'renewable.2',
#  'recipe2016',
#  'recipe',
#  'recipe.1',
#  'recipe.2',
#  'recipe.3',
#  'recipe.4',
#  'recipe.5',
#  'global warming,',
#  'global warming, .1',
#  'global warming, .2',
#  'stratospheric',
#  'ionizing',
#  'ozone formation,',
#  'fine particulate',
#  'ozone formation, .1',
#  'terrestrial',
#  'freshwater',
#  'marine',
#  'terrestrial.1',
#  'freshwater.1',
#  'marine.1',
#  'human .1',
#  'human .2',
#  'land use',
#  'mineral resource',
#  'fossil resource',
#  'water consumption,',
#  'water consumption,.1',
#  'water consumption, .1',
#  'ef 3.1',
#  'acidification',
#  'climate change',
#  'ecotoxicity.1',
#  'particulate',
#  'eutrophication,',
#  'eutrophication, .1',
#  'eutrophication,.1',
#  'human toxicity,',
#  'human toxicity, non-cancer',
#  'ionising radiation',
#  'land use.1',
#  'ozone depletion',
#  'photochemical ozone formation',
#  'resource use,',
#  'resource use,.1',
#  'water use',
#  'traci',
#  'traci.1',
#  'traci.2',
#  'traci.3',
#  'traci.4',
#  'traci.5',
#  'traci.6',
#  'traci.7',
#  'traci.8',
#  'traci.9',
#  'carbon.1',
#  'pollutants',
#  'water',
#  'biodiversity.1',
#  'resources',
#  'classyfire',
#  'chemicals,plastics, and wood',
#  'note:',
#  'unnamed: 107',
#  'unnamed: 110',
#  'unnamed: 118',
#  'source_file']

# %%
# drop the columns 
df.drop(columns=columns_to_remove, inplace=True)

# %%
df.head()
# Out:
#                                                    .     industry  \
# 0  A.010.02.101.240318 Leather Chrome tanning - h...  agriculture
# 1  A.010.02.102.240318 Leather Vegetable tanning ...  agriculture
# 2  A.010.02.103.230701 Wool (from Australia trans...  agriculture
# 3         A.010.02.104.230701 Wool at farm Australia  agriculture
# 4  A.010.02.105.230701 wool, greasy, at farm Aust...  agriculture
#
#                                           ..2  \
# 0  Materials, agricultural, animal production
# 1  Materials, agricultural, animal production
# 2  Materials, agricultural, animal production
# 3  Materials, agricultural, animal production
# 4  Materials, agricultural, animal production
#
#                                           process     carbon  region
# 0    Leather Chrome tanning - hides from Argentia  15.911109  Global
# 1   Leather Vegetable tanning - hides from Europe  17.967245  Global
# 2  Wool (from Australia transported to Rotterdam)  78.080353  Global
# 3                          Wool at farm Australia  77.760547  Global
# 4                 wool, greasy, at farm Australia  38.880273  Global

# %%
# save the df into the same file name
df.to_excel('/Users/rajatsharma/IBM-CarbonSense-powered-by-Watsonx/Data_processed/industry/agriculture.xlsx', index=False)

# %%
import pandas as pd
import os

def filter_industry_files(folder_path):
    # Columns to keep
    columns_to_keep = ['.', 'industry', '..2', 'process', 'carbon', 'region']

    # Loop through each file
    for filename in os.listdir(folder_path):
        if filename.endswith('.xlsx') and not filename.startswith('~$') and not filename.startswith('.'):
            file_path = os.path.join(folder_path, filename)

            try:
                # Read the Excel file with engine specified
                df = pd.read_excel(file_path, engine='openpyxl')

                # Filter columns
                df_filtered = df[[col for col in df.columns if col in columns_to_keep]]

                # Save filtered DataFrame
                df_filtered.to_excel(file_path, index=False, engine='openpyxl')
                print(f"✅ Processed: {filename}")

            except Exception as e:
                print(f"❌ Failed to process {filename}: {e}")

# Example usage
filter_industry_files('/Users/rajatsharma/IBM-CarbonSense-powered-by-Watsonx/Data_processed/electricity/')
# Out:
# ✅ Processed: electricity USA.xlsx
# ✅ Processed: electricity Canada.xlsx
# ✅ Processed: electricity general industry.xlsx
# ✅ Processed: electricity China.xlsx
# ✅ Processed: electricity EU .xlsx
# ✅ Processed: electricity Rest of the World.xlsx
# ✅ Processed: electricity India.xlsx
